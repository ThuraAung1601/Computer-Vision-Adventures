# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-8e323c50-48a3-4d69-acd6-adab05d2f3fa" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8e323c50-48a3-4d69-acd6-adab05d2f3fa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving groupbig.jpg to groupbig.jpg
# ...

# %%
import cv2
import matplotlib.pyplot as plt

modelFile = "/content/haarcascade_frontalface_default.xml"

def detectHC(imgpath):
    faceCascade = cv2.CascadeClassifier(modelFile)


    font = cv2.FONT_HERSHEY_SIMPLEX

    frame = cv2.imread(imgpath)
    frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    faces = faceCascade.detectMultiScale(
        gray,
        scaleFactor=1.1,
        minNeighbors=5,
        minSize=(200, 200),
        flags=cv2.CASCADE_SCALE_IMAGE
    )

    # Draw a rectangle around the faces
    for (x, y, w, h) in faces:
        cv2.rectangle(frame, (x, y), (x+w, y+h), (255, 0, 0), 3)
        cv2.putText(frame,'Face',(x, y), font, 2,(255,0,0),5)

    cv2.putText(frame,'Number of Faces : ' + str(len(faces)),(40, 40), font, 1,(255,0,0),3)
    plt.imshow(frame)
    plt.show()

# %%
detectHC('/content/groupbig.jpg')
