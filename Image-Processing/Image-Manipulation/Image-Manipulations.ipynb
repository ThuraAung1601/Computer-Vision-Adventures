# %% [markdown]
# # Image Manipulations

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image 
from IPython.display import Image
# %matplotlib inline

# %% [markdown]
# ## Access and maniputate intensity values of image pixels

# %%
# Read image as gray scale.
cb_img = cv2.imread("Images/checkerboard_18x18.png",0)

# Set color map to gray scale for proper rendering.
plt.imshow(cb_img, cmap='gray')

# print(cb_img) # Intensity values

# %%
# 0th row, 0th column
print("First pixel of the first black box", cb_img[0,0])

# 0th row, 6th column
print("First white pixel to the right of the first black box", cb_img[0,6])
# Out:
# First pixel of the first black box 0
# First white pixel to the right of the first black box 255

# %%
cb_img_copy = cb_img.copy()
cb_img_copy[2,2] = 200
cb_img_copy[2,3] = 200
cb_img_copy[3,2] = 200
cb_img_copy[3,3] = 200

# Same as above
# cb_img_copy[2:3,2:3] = 200

plt.imshow(cb_img_copy, cmap='gray')

# print(cb_img_copy)

# %% [markdown]
# ### Cropping Images
#
# Cropping an image is simply achieved by selecting a specific (pixel) region of the image.

# %%
img_NZ_bgr = cv2.imread("Images/New_Zealand_Boat.jpg",cv2.IMREAD_COLOR)
img_NZ_rgb = img_NZ_bgr[:,:,::-1] 

plt.imshow(img_NZ_rgb)

# %% [markdown]
# ### <font color="green">Crop out the middle region of the image</font>

# %%
cropped_region = img_NZ_rgb[200:400, 300:600]
plt.imshow(cropped_region)

# %% [markdown]
# ## Resize the image
#
# **resize(src, dsize[, dst[, fx[, fy[, interpolation]]]])**
#
#
# * src: It is the required input image, it could be a string with the path of the input image (eg: ‘test_image.png’).
# * dsize: It is the desired size of the output image, it can be a new height and width.
# * fx: Scale factor along the horizontal axis.
# * fy: Scale factor along the vertical axis.
# * interpolation: It gives us the option of different methods of resizing the image.

# %%
scale_up_x = 2
scale_up_y = 2
# scale_down = 0.6 # For scaling down use 0 <= val <= 1

# dsize is None here
resized_cropped_region_2x = cv2.resize(cropped_region,None,fx=scale_up_x, fy=scale_up_y,interpolation= cv2.INTER_NEAREST)

plt.imshow(resized_cropped_region_2x)

# %%
desired_width = 100
desired_height = 200
dim = (desired_width, desired_height)

# Resize background image to sae size as logo image
resized_cropped_region = cv2.resize(cropped_region, dsize=dim, interpolation=cv2.INTER_AREA)
plt.imshow(resized_cropped_region)

# %%
# Swap channel order
resized_cropped_region_2x = resized_cropped_region_2x[:,:,::-1]

# Save resized image to disk
cv2.imwrite("Images/resized_cropped_region_2x.png", resized_cropped_region_2x)

# Display the cropped and resized image
Image(filename='Images/resized_cropped_region_2x.png')

# %%
# Swap channel order
cropped_region = cropped_region[:,:,::-1]

# Save cropped 'region'
cv2.imwrite("Images/cropped_region.png", cropped_region)

# Display the cropped and resized image
Image(filename="Images/cropped_region.png")

# %% [markdown]
# ## Flip
#
# **dst = cv.flip( src, flipCode )**
#
# * dst: output array of the same size and type as src.
#
# * src: input image
# * flipCode: a flag to specify how to flip the array;
#     - 0 means flipping around the x-axis and
#     - Positive value (for example, 1) means flipping around y-axis.
#     - Negative value (for example, -1) means flipping around both axes.

# %%
img_NZ_rgb_flipped_horz = cv2.flip(img_NZ_rgb, 1)
img_NZ_rgb_flipped_vert = cv2.flip(img_NZ_rgb, 0)
img_NZ_rgb_flipped_both = cv2.flip(img_NZ_rgb, -1)

# Show the images
plt.figure(figsize=[18,5])
plt.subplot(141);plt.imshow(img_NZ_rgb_flipped_horz);plt.title("Horizontal Flip");
plt.subplot(142);plt.imshow(img_NZ_rgb_flipped_vert);plt.title("Vertical Flip");
plt.subplot(143);plt.imshow(img_NZ_rgb_flipped_both);plt.title("Both Flipped");
plt.subplot(144);plt.imshow(img_NZ_rgb);plt.title("Original");
